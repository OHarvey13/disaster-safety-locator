# %%
# Predict Hurricane size using Random Forest

import numpy as np
import pandas as pd
import re, math, os, warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import joblib

import matplotlib.pyplot as plt
import seaborn as sns


read_csv = pd.read_csv("Hurricane_dataset - Sheet1.csv")
df = pd.DataFrame(read_csv)
df.head()
# Out:
#    num       Date   Time    Lat   Long  Max_Winds_kt  SSHWS RMW_nm  \
# 0    1  7/11/1901  0700Z  36.0N  75.8W            70      1    ---
# 1    2  8/14/1901  2100Z  29.3N  89.6W            75      1    ---
# 2    3  8/15/1901  1700Z  30.4N  88.8W            75      1     35
# 3    4  9/11/1903  2300Z  26.1N  80.1W            75      1     45
# 4    5  9/13/1903  2300Z  30.1N  85.6W            80      1    ---
#
#    Central_Pressure  OCI_mb  Size_nm States_Affected       Strom_Name  \
# 0              -983    1013      175             NC1  ---------------
# 1              -973    1010      300             LA1  ---------------
# 2               973    1010      300         MS1,AL1  ---------------
# 3               976    1013      150            CFL1  ---------------
# 4              -974    1014      200            AFL1  ---------------
#
#   Unnamed: 13 Unnamed: 14
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   num               170 non-null    int64
#  1   Date              170 non-null    object
#  2   Time              170 non-null    object
#  3   Lat               170 non-null    object
#  4   Long              170 non-null    object
#  5   Max_Winds_kt      170 non-null    int64
#  6   SSHWS             170 non-null    int64
#  7   RMW_nm            170 non-null    object
#  8   Central_Pressure  170 non-null    int64
#  9   OCI_mb            170 non-null    int64
#  10  Size_nm           170 non-null    int64
#  11  States_Affected   170 non-null    object
#  12  Strom_Name        170 non-null    object
#  13  Unnamed: 13       16 non-null     object
#  14  Unnamed: 14       3 non-null      object
# dtypes: int64(6), object(9)
# memory usage: 20.1+ KB

# %%
# Drop unnamed/junk columns if any
for c in list(df.columns):
    if "Unnamed" in c: # drop any columns that are unnamed
        df.drop(columns=c, inplace=True, errors="ignore")

# Normalize column names
df.columns = [c.strip().replace(" ", "_") for c in df.columns] # repalce the underscores with a space


def parse_lat(x):
    if pd.isna(x): return np.nan # check if input is null and if so return NaN
    s = str(x).strip() # inputs will look like 35.6N and we are converting into a string and removing trailing/leading spaces
    m = re.match(r"^([+-]?\d+(?:\.\d+)?)([NnSs])$", s) # we use a regular expression to see if a string looks like a number followed by N or S ([NnSs]) caputres direction
    if m: # if match exists
        val = float(m.group(1)) # convert the numeric part to a float
        return val if m.group(2).upper()=="N" else -val # convert the float to negative if S or keep pos if N (will help with determingn what is in northern hemisphere and be more compatible with our GIS data)
    try: return float(s)
    except: return np.nan

def parse_lon(x):
    if pd.isna(x): return np.nan
    s = str(x).strip()
    m = re.match(r"^([+-]?\d+(?:\.\d+)?)([EeWw])$", s)
    if m:
        val = float(m.group(1))
        return -val if m.group(2).upper()=="W" else val
    try: return float(s)
    except: return np.nan

def parse_rmw(x):
    if pd.isna(x): return np.nan
    s = str(x).strip()
    if s in {"---","--","-"}: return np.nan
    s = s.replace(",", "")
    try: return float(s)
    except: return np.nan

def parse_pressure(x):
    if pd.isna(x): return np.nan
    s = str(x).strip().replace(",", "")
    m = re.match(r"^\(?\s*(-?\d+(?:\.\d+)?)\s*\)?$", s)  # handles (983) or -983
    if m: return abs(float(m.group(1)))
    try: return abs(float(s))
    except: return np.nan

def parse_time_to_hour(t):
    if pd.isna(t): return np.nan
    s = str(t).strip().upper().replace("Z","")
    m = re.match(r"^(\d{2})(\d{2})$", s)  # 2300 -> 23
    if m: return int(m.group(1))
    try:
        h = int(s)
        return h if 0 <= h <= 23 else np.nan
    except:
        return np.nan

# %%
# Parse and clean columns only if they are present in the dataset by calling previous functions
if "Lat" in df.columns: df["Lat"] = df["Lat"].apply(parse_lat)
if "Long" in df.columns: df["Long"] = df["Long"].apply(parse_lon)
if "RMW_nm" in df.columns: df["RMW_nm"] = df["RMW_nm"].apply(parse_rmw)

if "Central_Pressure" in df.columns: df["Central_Pressure"] = df["Central_Pressure"].apply(parse_pressure)
if "OCI_mb" in df.columns: df["OCI_mb"] = pd.to_numeric(df["OCI_mb"], errors="coerce")

# Date & time to numeric parts
if "Date" in df.columns:
    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
    df["Year"]  = df["Date"].dt.year
    df["Month"] = df["Date"].dt.month
    df["Day"]   = df["Date"].dt.day

if "Time" in df.columns:
    df["Hour"] = df["Time"].apply(parse_time_to_hour)

# Simple derived features
if "Lat" in df.columns:
    df["Abs_Lat"] = df["Lat"].abs()
if {"Max_Winds_kt", "Central_Pressure"}.issubset(df.columns):
    df["Wind_to_Pressure"] = df["Max_Winds_kt"] / (df["Central_Pressure"] + 1e-6)

print("After cleaning shape:", df.shape)
df.info()
# Out:
# After cleaning shape: (170, 19)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   num               170 non-null    int64
#  1   Date              151 non-null    datetime64[ns]
#  2   Time              170 non-null    object
#  3   Lat               170 non-null    float64
#  4   Long              170 non-null    float64
#  5   Max_Winds_kt      170 non-null    int64
#  6   SSHWS             170 non-null    int64
#  7   RMW_nm            130 non-null    float64
#  8   Central_Pressure  170 non-null    float64
#  9   OCI_mb            170 non-null    int64
#  10  Size_nm           170 non-null    int64
#  11  States_Affected   170 non-null    object
#  12  Strom_Name        170 non-null    object
#  13  Year              151 non-null    float64
#  14  Month             151 non-null    float64
#  15  Day               151 non-null    float64
#  16  Hour              170 non-null    int64
#  17  Abs_Lat           170 non-null    float64
#  18  Wind_to_Pressure  170 non-null    float64
# dtypes: datetime64[ns](1), float64(9), int64(6), object(3)
# memory usage: 25.4+ KB

# %%
# We know Central Pressure is the one that affects this the most
df = df.drop(['States_Affected', 'Strom_Name', 'Time'], axis=1)

# %%
df.head()
# Out:
#    num       Date   Lat  Long  Max_Winds_kt  SSHWS  RMW_nm  Central_Pressure  \
# 0    1 1901-07-11  36.0 -75.8            70      1     NaN             983.0
# 1    2 1901-08-14  29.3 -89.6            75      1     NaN             973.0
# 2    3 1901-08-15  30.4 -88.8            75      1    35.0             973.0
# 3    4 1903-09-11  26.1 -80.1            75      1    45.0             976.0
# 4    5 1903-09-13  30.1 -85.6            80      1     NaN             974.0
#
#    OCI_mb  Size_nm    Year  Month   Day  Hour  Abs_Lat  Wind_to_Pressure
# 0    1013      175  1901.0    7.0  11.0     7     36.0          0.071211
# 1    1010      300  1901.0    8.0  14.0    21     29.3          0.077081
# 2    1010      300  1901.0    8.0  15.0    17     30.4          0.077081
# 3    1013      150  1903.0    9.0  11.0    23     26.1          0.076844
# 4    1014      200  1903.0    9.0  13.0    23     30.1          0.082136

# %%
sns.heatmap(df.corr())
# Shows teh
# Out:
# <Axes: >

# %%
 #  IQR filtering so make sure we are keeping values that are near the Q1 or Q3 or between

def remove_outliers (df, columns):
  for col_name in columns:
        Q1 = df[col_name].quantile(0.25)
        Q3 = df[col_name].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        df = df[(df[col_name] >= lower) & (df[col_name] <= upper)]

  return df

# %%
df_new=remove_outliers(df,df.columns)
df_new.head()
# Out:
#     num       Date   Lat  Long  Max_Winds_kt  SSHWS  RMW_nm  Central_Pressure  \
# 2     3 1901-08-15  30.4 -88.8            75      1    35.0             973.0
# 3     4 1903-09-11  26.1 -80.1            75      1    45.0             976.0
# 9    10 1906-06-17  25.2 -80.7            75      1    25.0             979.0
# 10   11 1906-09-17  33.3 -79.2            80      1    30.0             977.0
# 11   12 1906-09-27  30.2 -88.6            95      2    45.0             958.0
#
#     OCI_mb  Size_nm    Year  Month   Day  Hour  Abs_Lat  Wind_to_Pressure
# 2     1010      300  1901.0    8.0  15.0    17     30.4          0.077081
# 3     1013      150  1903.0    9.0  11.0    23     26.1          0.076844
# 9     1012      300  1906.0    6.0  17.0     8     25.2          0.076609
# 10    1014      175  1906.0    9.0  17.0    22     33.3          0.081883
# 11    1009      250  1906.0    9.0  27.0    11     30.2          0.099165

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
scaler=MinMaxScaler() # we are about to scale all the values to be within 0-1 range

# %%
x = df.drop(['Size_nm', "Date"], axis=1)
y = df['Size_nm']

# %%
x=scaler.fit_transform(x)
x
y = scaler.fit_transform(y.values.reshape(-1, 1))
x_train=np.array(x)
y_train=np.array(y)
mask = ~np.isnan(x_train).any(axis=1)
x_train = x_train[mask]
y_train = y_train[mask]
print(np.isnan(x_train).sum())
print(np.isnan(y_train).sum())
# Out:
# 0
# 0

# %%
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train,random_state=42,test_size=0.2)
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.optimizers import Adam, AdamW
from keras.losses import MeanSquaredError, MeanAbsoluteError, LogCosh
from keras.layers import Dense, Dropout, LeakyReLU
# class myCallback(tf.keras.callbacks.Callback):
#   def on_epoch_end(self, epoch, logs={}):
#       if(logs.get('mae')>0.99):
#         print("\nReached 99% accuracy so cancelling training!")
#         self.model.stop_training = True


# callbacks = myCallback()
model=Sequential([
    Dense(64, input_dim=x_train.shape[1]),
    LeakyReLU(0.1),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1)
]

)
opt=Adam(learning_rate=0.001)
model.compile(loss = LogCosh() , optimizer = opt , metrics = ['mae'])
history = model.fit(x_train , y_train , epochs = 300 , batch_size = 80, validation_split = 0.2)
# Out:
# Epoch 1/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0644 - mae: 0.3111 - val_loss: 0.0716 - val_mae: 0.3305
# Epoch 2/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0570 - mae: 0.2917 - val_loss: 0.0539 - val_mae: 0.2782
# Epoch 3/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0462 - mae: 0.2595 - val_loss: 0.0395 - val_mae: 0.2315
# Epoch 4/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0327 - mae: 0.2041 - val_loss: 0.0288 - val_mae: 0.1965
# Epoch 5/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0248 - mae: 0.1713 - val_loss: 0.0216 - val_mae: 0.1674
# Epoch 6/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0260 - mae: 0.1854 - val_loss: 0.0175 - val_mae: 0.1450
# Epoch 7/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0231 - mae: 0.1699 - val_loss: 0.0159 - val_mae: 0.1364
# Epoch 8/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0260 - mae: 0.1756 - val_loss: 0.0157 - val_mae: 0.1360
# Epoch 9/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0263 - mae: 0.1900 - val_loss: 0.0162 - val_mae: 0.1383
# Epoch 10/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0297 - mae: 0.2002 - val_loss: 0.0164 - val_mae: 0.1403
# Epoch 11/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0273 - mae: 0.1955 - val_loss: 0.0162 - val_mae: 0.1396
# Epoch 12/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0303 - mae: 0.2015 - val_loss: 0.0159 - val_mae: 0.1370
# Epoch 13/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0276 - mae: 0.1947 - val_loss: 0.0154 - val_mae: 0.1351
# Epoch 14/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0248 - mae: 0.1835 - val_loss: 0.0152 - val_mae: 0.1339
# Epoch 15/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0195 - mae: 0.1609 - val_loss: 0.0153 - val_mae: 0.1352
# Epoch 16/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0207 - mae: 0.1623 - val_loss: 0.0160 - val_mae: 0.1394
# Epoch 17/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0216 - mae: 0.1724 - val_loss: 0.0170 - val_mae: 0.1455
# Epoch 18/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0178 - mae: 0.1534 - val_loss: 0.0180 - val_mae: 0.1527
# Epoch 19/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0222 - mae: 0.1688 - val_loss: 0.0191 - val_mae: 0.1594
# Epoch 20/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0192 - mae: 0.1594 - val_loss: 0.0203 - val_mae: 0.1652
# Epoch 21/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0187 - mae: 0.1589 - val_loss: 0.0213 - val_mae: 0.1709
# Epoch 22/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0194 - mae: 0.1563 - val_loss: 0.0222 - val_mae: 0.1755
# Epoch 23/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0215 - mae: 0.1681 - val_loss: 0.0229 - val_mae: 0.1788
# Epoch 24/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0195 - mae: 0.1600 - val_loss: 0.0235 - val_mae: 0.1813
# Epoch 25/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0199 - mae: 0.1584 - val_loss: 0.0237 - val_mae: 0.1825
# Epoch 26/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0217 - mae: 0.1616 - val_loss: 0.0236 - val_mae: 0.1821
# Epoch 27/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0181 - mae: 0.1538 - val_loss: 0.0233 - val_mae: 0.1807
# Epoch 28/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0183 - mae: 0.1567 - val_loss: 0.0228 - val_mae: 0.1786
# Epoch 29/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0185 - mae: 0.1571 - val_loss: 0.0222 - val_mae: 0.1757
# Epoch 30/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0182 - mae: 0.1593 - val_loss: 0.0214 - val_mae: 0.1724
# Epoch 31/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0169 - mae: 0.1437 - val_loss: 0.0207 - val_mae: 0.1685
# Epoch 32/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0175 - mae: 0.1483 - val_loss: 0.0199 - val_mae: 0.1644
# Epoch 33/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0175 - mae: 0.1497 - val_loss: 0.0191 - val_mae: 0.1599
# Epoch 34/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0175 - mae: 0.1450 - val_loss: 0.0185 - val_mae: 0.1562
# Epoch 35/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0158 - mae: 0.1368 - val_loss: 0.0179 - val_mae: 0.1531
# Epoch 36/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0206 - mae: 0.1632 - val_loss: 0.0175 - val_mae: 0.1503
# Epoch 37/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0176 - mae: 0.1521 - val_loss: 0.0171 - val_mae: 0.1475
# Epoch 38/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0158 - mae: 0.1448 - val_loss: 0.0168 - val_mae: 0.1453
# Epoch 39/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0170 - mae: 0.1497 - val_loss: 0.0166 - val_mae: 0.1434
# Epoch 40/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0158 - mae: 0.1432 - val_loss: 0.0164 - val_mae: 0.1418
# Epoch 41/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0165 - mae: 0.1573 - val_loss: 0.0163 - val_mae: 0.1408
# Epoch 42/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0179 - mae: 0.1507 - val_loss: 0.0162 - val_mae: 0.1406
# Epoch 43/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0169 - mae: 0.1509 - val_loss: 0.0163 - val_mae: 0.1409
# Epoch 44/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0138 - mae: 0.1347 - val_loss: 0.0164 - val_mae: 0.1416
# Epoch 45/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0148 - mae: 0.1369 - val_loss: 0.0165 - val_mae: 0.1425
# Epoch 46/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0160 - mae: 0.1458 - val_loss: 0.0167 - val_mae: 0.1437
# Epoch 47/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0140 - mae: 0.1332 - val_loss: 0.0169 - val_mae: 0.1452
# Epoch 48/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0161 - mae: 0.1434 - val_loss: 0.0172 - val_mae: 0.1470
# Epoch 49/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0177 - mae: 0.1578 - val_loss: 0.0175 - val_mae: 0.1491
# Epoch 50/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0164 - mae: 0.1481 - val_loss: 0.0179 - val_mae: 0.1515
# Epoch 51/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0173 - mae: 0.1510 - val_loss: 0.0183 - val_mae: 0.1534
# Epoch 52/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0138 - mae: 0.1292 - val_loss: 0.0186 - val_mae: 0.1550
# Epoch 53/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0163 - mae: 0.1425 - val_loss: 0.0190 - val_mae: 0.1563
# Epoch 54/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0159 - mae: 0.1458 - val_loss: 0.0192 - val_mae: 0.1573
# Epoch 55/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0146 - mae: 0.1386 - val_loss: 0.0194 - val_mae: 0.1580
# Epoch 56/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0127 - mae: 0.1270 - val_loss: 0.0196 - val_mae: 0.1583
# Epoch 57/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0154 - mae: 0.1400 - val_loss: 0.0196 - val_mae: 0.1583
# Epoch 58/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0144 - mae: 0.1364 - val_loss: 0.0196 - val_mae: 0.1579
# Epoch 59/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0147 - mae: 0.1382 - val_loss: 0.0195 - val_mae: 0.1570
# Epoch 60/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0134 - mae: 0.1250 - val_loss: 0.0193 - val_mae: 0.1556
# Epoch 61/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0137 - mae: 0.1352 - val_loss: 0.0190 - val_mae: 0.1540
# Epoch 62/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0141 - mae: 0.1342 - val_loss: 0.0188 - val_mae: 0.1524
# Epoch 63/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0123 - mae: 0.1231 - val_loss: 0.0186 - val_mae: 0.1510
# Epoch 64/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0145 - mae: 0.1382 - val_loss: 0.0185 - val_mae: 0.1503
# Epoch 65/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0137 - mae: 0.1348 - val_loss: 0.0185 - val_mae: 0.1495
# Epoch 66/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0119 - mae: 0.1256 - val_loss: 0.0185 - val_mae: 0.1491
# Epoch 67/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0152 - mae: 0.1350 - val_loss: 0.0185 - val_mae: 0.1490
# Epoch 68/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0130 - mae: 0.1277 - val_loss: 0.0185 - val_mae: 0.1486
# Epoch 69/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0141 - mae: 0.1371 - val_loss: 0.0186 - val_mae: 0.1489
# Epoch 70/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0135 - mae: 0.1322 - val_loss: 0.0187 - val_mae: 0.1496
# Epoch 71/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0126 - mae: 0.1272 - val_loss: 0.0188 - val_mae: 0.1501
# Epoch 72/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0110 - mae: 0.1181 - val_loss: 0.0189 - val_mae: 0.1504
# Epoch 73/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0124 - mae: 0.1243 - val_loss: 0.0189 - val_mae: 0.1505
# Epoch 74/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0128 - mae: 0.1282 - val_loss: 0.0190 - val_mae: 0.1513
# Epoch 75/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0126 - mae: 0.1246 - val_loss: 0.0192 - val_mae: 0.1522
# Epoch 76/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0135 - mae: 0.1319 - val_loss: 0.0194 - val_mae: 0.1534
# Epoch 77/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0125 - mae: 0.1268 - val_loss: 0.0194 - val_mae: 0.1538
# Epoch 78/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0146 - mae: 0.1328 - val_loss: 0.0194 - val_mae: 0.1538
# Epoch 79/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0129 - mae: 0.1321 - val_loss: 0.0193 - val_mae: 0.1537
# Epoch 80/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0117 - mae: 0.1235 - val_loss: 0.0191 - val_mae: 0.1533
# Epoch 81/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0119 - mae: 0.1226 - val_loss: 0.0190 - val_mae: 0.1527
# Epoch 82/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0116 - mae: 0.1167 - val_loss: 0.0188 - val_mae: 0.1520
# Epoch 83/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0137 - mae: 0.1310 - val_loss: 0.0185 - val_mae: 0.1511
# Epoch 84/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0120 - mae: 0.1262 - val_loss: 0.0184 - val_mae: 0.1510
# Epoch 85/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0116 - mae: 0.1189 - val_loss: 0.0184 - val_mae: 0.1513
# Epoch 86/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0127 - mae: 0.1236 - val_loss: 0.0184 - val_mae: 0.1517
# Epoch 87/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0113 - mae: 0.1238 - val_loss: 0.0185 - val_mae: 0.1523
# Epoch 88/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - loss: 0.0118 - mae: 0.1188 - val_loss: 0.0186 - val_mae: 0.1527
# Epoch 89/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0119 - mae: 0.1221 - val_loss: 0.0187 - val_mae: 0.1531
# Epoch 90/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0109 - mae: 0.1163 - val_loss: 0.0188 - val_mae: 0.1537
# Epoch 91/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0118 - mae: 0.1193 - val_loss: 0.0189 - val_mae: 0.1545
# Epoch 92/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0123 - mae: 0.1195 - val_loss: 0.0190 - val_mae: 0.1551
# Epoch 93/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.0122 - mae: 0.1304 - val_loss: 0.0192 - val_mae: 0.1559
# Epoch 94/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.0127 - mae: 0.1256 - val_loss: 0.0193 - val_mae: 0.1562
# Epoch 95/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0105 - mae: 0.1149 - val_loss: 0.0193 - val_mae: 0.1561
# Epoch 96/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.0113 - mae: 0.1241 - val_loss: 0.0192 - val_mae: 0.1551
# Epoch 97/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0102 - mae: 0.1156 - val_loss: 0.0190 - val_mae: 0.1539
# Epoch 98/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0118 - mae: 0.1208 - val_loss: 0.0189 - val_mae: 0.1529
# Epoch 99/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0109 - mae: 0.1225 - val_loss: 0.0189 - val_mae: 0.1529
# Epoch 100/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0092 - mae: 0.1085 - val_loss: 0.0189 - val_mae: 0.1527
# Epoch 101/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0112 - mae: 0.1201 - val_loss: 0.0190 - val_mae: 0.1530
# Epoch 102/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0089 - mae: 0.1079 - val_loss: 0.0193 - val_mae: 0.1542
# Epoch 103/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0121 - mae: 0.1237 - val_loss: 0.0196 - val_mae: 0.1554
# Epoch 104/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0104 - mae: 0.1172 - val_loss: 0.0196 - val_mae: 0.1555
# Epoch 105/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0122 - mae: 0.1249 - val_loss: 0.0196 - val_mae: 0.1554
# Epoch 106/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0114 - mae: 0.1191 - val_loss: 0.0194 - val_mae: 0.1542
# Epoch 107/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0107 - mae: 0.1167 - val_loss: 0.0190 - val_mae: 0.1523
# Epoch 108/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0094 - mae: 0.1116 - val_loss: 0.0187 - val_mae: 0.1509
# Epoch 109/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0111 - mae: 0.1158 - val_loss: 0.0184 - val_mae: 0.1497
# Epoch 110/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0109 - mae: 0.1142 - val_loss: 0.0181 - val_mae: 0.1483
# Epoch 111/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0119 - mae: 0.1226 - val_loss: 0.0179 - val_mae: 0.1472
# Epoch 112/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0091 - mae: 0.1102 - val_loss: 0.0178 - val_mae: 0.1471
# Epoch 113/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0099 - mae: 0.1150 - val_loss: 0.0179 - val_mae: 0.1478
# Epoch 114/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0113 - mae: 0.1188 - val_loss: 0.0181 - val_mae: 0.1488
# Epoch 115/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0113 - mae: 0.1191 - val_loss: 0.0181 - val_mae: 0.1489
# Epoch 116/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0089 - mae: 0.1037 - val_loss: 0.0182 - val_mae: 0.1495
# Epoch 117/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0094 - mae: 0.1118 - val_loss: 0.0185 - val_mae: 0.1510
# Epoch 118/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0094 - mae: 0.1128 - val_loss: 0.0189 - val_mae: 0.1524
# Epoch 119/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0100 - mae: 0.1133 - val_loss: 0.0191 - val_mae: 0.1534
# Epoch 120/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0086 - mae: 0.1052 - val_loss: 0.0191 - val_mae: 0.1534
# Epoch 121/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0108 - mae: 0.1150 - val_loss: 0.0193 - val_mae: 0.1539
# Epoch 122/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0099 - mae: 0.1116 - val_loss: 0.0191 - val_mae: 0.1534
# Epoch 123/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0093 - mae: 0.1070 - val_loss: 0.0189 - val_mae: 0.1520
# Epoch 124/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0109 - mae: 0.1182 - val_loss: 0.0184 - val_mae: 0.1498
# Epoch 125/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0091 - mae: 0.1111 - val_loss: 0.0180 - val_mae: 0.1481
# Epoch 126/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0089 - mae: 0.1066 - val_loss: 0.0179 - val_mae: 0.1473
# Epoch 127/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0095 - mae: 0.1025 - val_loss: 0.0177 - val_mae: 0.1465
# Epoch 128/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0085 - mae: 0.1042 - val_loss: 0.0175 - val_mae: 0.1455
# Epoch 129/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0094 - mae: 0.1151 - val_loss: 0.0173 - val_mae: 0.1444
# Epoch 130/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0108 - mae: 0.1130 - val_loss: 0.0174 - val_mae: 0.1450
# Epoch 131/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0097 - mae: 0.1128 - val_loss: 0.0176 - val_mae: 0.1459
# Epoch 132/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0103 - mae: 0.1134 - val_loss: 0.0179 - val_mae: 0.1479
# Epoch 133/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0087 - mae: 0.1037 - val_loss: 0.0183 - val_mae: 0.1500
# Epoch 134/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0081 - mae: 0.0987 - val_loss: 0.0187 - val_mae: 0.1519
# Epoch 135/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0099 - mae: 0.1130 - val_loss: 0.0189 - val_mae: 0.1527
# Epoch 136/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0106 - mae: 0.1158 - val_loss: 0.0190 - val_mae: 0.1529
# Epoch 137/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0090 - mae: 0.1052 - val_loss: 0.0189 - val_mae: 0.1524
# Epoch 138/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0086 - mae: 0.1058 - val_loss: 0.0188 - val_mae: 0.1517
# Epoch 139/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0087 - mae: 0.1053 - val_loss: 0.0187 - val_mae: 0.1510
# Epoch 140/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0086 - mae: 0.1004 - val_loss: 0.0184 - val_mae: 0.1497
# Epoch 141/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0080 - mae: 0.0997 - val_loss: 0.0182 - val_mae: 0.1484
# Epoch 142/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0098 - mae: 0.1091 - val_loss: 0.0179 - val_mae: 0.1466
# Epoch 143/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0092 - mae: 0.1069 - val_loss: 0.0176 - val_mae: 0.1448
# Epoch 144/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0079 - mae: 0.1012 - val_loss: 0.0174 - val_mae: 0.1437
# Epoch 145/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0093 - mae: 0.1074 - val_loss: 0.0173 - val_mae: 0.1431
# Epoch 146/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0074 - mae: 0.0965 - val_loss: 0.0172 - val_mae: 0.1423
# Epoch 147/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0089 - mae: 0.1047 - val_loss: 0.0171 - val_mae: 0.1420
# Epoch 148/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0087 - mae: 0.0990 - val_loss: 0.0173 - val_mae: 0.1430
# Epoch 149/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0090 - mae: 0.1100 - val_loss: 0.0175 - val_mae: 0.1440
# Epoch 150/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0077 - mae: 0.0941 - val_loss: 0.0177 - val_mae: 0.1451
# Epoch 151/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0082 - mae: 0.1015 - val_loss: 0.0181 - val_mae: 0.1469
# Epoch 152/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0077 - mae: 0.0978 - val_loss: 0.0185 - val_mae: 0.1487
# Epoch 153/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0087 - mae: 0.1083 - val_loss: 0.0188 - val_mae: 0.1500
# Epoch 154/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0076 - mae: 0.0991 - val_loss: 0.0190 - val_mae: 0.1510
# Epoch 155/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0082 - mae: 0.0999 - val_loss: 0.0190 - val_mae: 0.1511
# Epoch 156/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0079 - mae: 0.1009 - val_loss: 0.0188 - val_mae: 0.1496
# Epoch 157/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0096 - mae: 0.1108 - val_loss: 0.0186 - val_mae: 0.1479
# Epoch 158/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0081 - mae: 0.1026 - val_loss: 0.0182 - val_mae: 0.1457
# Epoch 159/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0097 - mae: 0.1142 - val_loss: 0.0180 - val_mae: 0.1443
# Epoch 160/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0086 - mae: 0.1023 - val_loss: 0.0178 - val_mae: 0.1432
# Epoch 161/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0085 - mae: 0.1028 - val_loss: 0.0177 - val_mae: 0.1424
# Epoch 162/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0073 - mae: 0.0932 - val_loss: 0.0176 - val_mae: 0.1419
# Epoch 163/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0085 - mae: 0.0982 - val_loss: 0.0176 - val_mae: 0.1417
# Epoch 164/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0113 - mae: 0.1266 - val_loss: 0.0175 - val_mae: 0.1405
# Epoch 165/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0085 - mae: 0.1022 - val_loss: 0.0174 - val_mae: 0.1400
# Epoch 166/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0089 - mae: 0.1113 - val_loss: 0.0176 - val_mae: 0.1409
# Epoch 167/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0076 - mae: 0.1022 - val_loss: 0.0178 - val_mae: 0.1422
# Epoch 168/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0079 - mae: 0.0995 - val_loss: 0.0180 - val_mae: 0.1433
# Epoch 169/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0086 - mae: 0.1049 - val_loss: 0.0182 - val_mae: 0.1444
# Epoch 170/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0091 - mae: 0.1084 - val_loss: 0.0184 - val_mae: 0.1453
# Epoch 171/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0096 - mae: 0.1121 - val_loss: 0.0184 - val_mae: 0.1455
# Epoch 172/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0073 - mae: 0.0987 - val_loss: 0.0183 - val_mae: 0.1454
# Epoch 173/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0081 - mae: 0.1064 - val_loss: 0.0181 - val_mae: 0.1445
# Epoch 174/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0087 - mae: 0.1074 - val_loss: 0.0179 - val_mae: 0.1441
# Epoch 175/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0085 - mae: 0.1092 - val_loss: 0.0177 - val_mae: 0.1427
# Epoch 176/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0086 - mae: 0.1046 - val_loss: 0.0175 - val_mae: 0.1420
# Epoch 177/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0093 - mae: 0.1070 - val_loss: 0.0176 - val_mae: 0.1423
# Epoch 178/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0072 - mae: 0.0948 - val_loss: 0.0176 - val_mae: 0.1420
# Epoch 179/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0079 - mae: 0.0981 - val_loss: 0.0177 - val_mae: 0.1422
# Epoch 180/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0075 - mae: 0.0992 - val_loss: 0.0179 - val_mae: 0.1429
# Epoch 181/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0084 - mae: 0.1044 - val_loss: 0.0180 - val_mae: 0.1429
# Epoch 182/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0071 - mae: 0.0987 - val_loss: 0.0180 - val_mae: 0.1423
# Epoch 183/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0076 - mae: 0.0996 - val_loss: 0.0180 - val_mae: 0.1418
# Epoch 184/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0072 - mae: 0.0976 - val_loss: 0.0178 - val_mae: 0.1408
# Epoch 185/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0085 - mae: 0.1005 - val_loss: 0.0175 - val_mae: 0.1398
# Epoch 186/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0090 - mae: 0.1089 - val_loss: 0.0173 - val_mae: 0.1391
# Epoch 187/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0075 - mae: 0.1001 - val_loss: 0.0173 - val_mae: 0.1387
# Epoch 188/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0081 - mae: 0.1023 - val_loss: 0.0173 - val_mae: 0.1390
# Epoch 189/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0084 - mae: 0.1069 - val_loss: 0.0175 - val_mae: 0.1396
# Epoch 190/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0063 - mae: 0.0894 - val_loss: 0.0176 - val_mae: 0.1401
# Epoch 191/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0074 - mae: 0.0947 - val_loss: 0.0178 - val_mae: 0.1406
# Epoch 192/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0075 - mae: 0.1020 - val_loss: 0.0180 - val_mae: 0.1412
# Epoch 193/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0085 - mae: 0.1069 - val_loss: 0.0182 - val_mae: 0.1420
# Epoch 194/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0079 - mae: 0.0960 - val_loss: 0.0184 - val_mae: 0.1423
# Epoch 195/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0079 - mae: 0.0993 - val_loss: 0.0185 - val_mae: 0.1425
# Epoch 196/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0071 - mae: 0.0900 - val_loss: 0.0185 - val_mae: 0.1422
# Epoch 197/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - loss: 0.0083 - mae: 0.1055 - val_loss: 0.0183 - val_mae: 0.1415
# Epoch 198/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0089 - mae: 0.1088 - val_loss: 0.0180 - val_mae: 0.1403
# Epoch 199/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0089 - mae: 0.1035 - val_loss: 0.0176 - val_mae: 0.1384
# Epoch 200/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0069 - mae: 0.0935 - val_loss: 0.0173 - val_mae: 0.1368
# Epoch 201/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 0.0071 - mae: 0.0933 - val_loss: 0.0172 - val_mae: 0.1360
# Epoch 202/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 0.0075 - mae: 0.1004 - val_loss: 0.0170 - val_mae: 0.1354
# Epoch 203/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - loss: 0.0086 - mae: 0.1095 - val_loss: 0.0172 - val_mae: 0.1362
# Epoch 204/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0064 - mae: 0.0878 - val_loss: 0.0173 - val_mae: 0.1365
# Epoch 205/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0065 - mae: 0.0888 - val_loss: 0.0175 - val_mae: 0.1379
# Epoch 206/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0074 - mae: 0.0972 - val_loss: 0.0178 - val_mae: 0.1394
# Epoch 207/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0084 - mae: 0.1017 - val_loss: 0.0179 - val_mae: 0.1401
# Epoch 208/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0053 - mae: 0.0841 - val_loss: 0.0177 - val_mae: 0.1401
# Epoch 209/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0068 - mae: 0.0979 - val_loss: 0.0176 - val_mae: 0.1398
# Epoch 210/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0070 - mae: 0.0945 - val_loss: 0.0175 - val_mae: 0.1397
# Epoch 211/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0065 - mae: 0.0882 - val_loss: 0.0174 - val_mae: 0.1396
# Epoch 212/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0079 - mae: 0.1011 - val_loss: 0.0172 - val_mae: 0.1390
# Epoch 213/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0062 - mae: 0.0902 - val_loss: 0.0172 - val_mae: 0.1391
# Epoch 214/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0074 - mae: 0.0973 - val_loss: 0.0174 - val_mae: 0.1404
# Epoch 215/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0078 - mae: 0.1031 - val_loss: 0.0178 - val_mae: 0.1418
# Epoch 216/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0076 - mae: 0.0987 - val_loss: 0.0181 - val_mae: 0.1429
# Epoch 217/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0086 - mae: 0.1049 - val_loss: 0.0184 - val_mae: 0.1442
# Epoch 218/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0080 - mae: 0.1009 - val_loss: 0.0188 - val_mae: 0.1455
# Epoch 219/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0067 - mae: 0.0939 - val_loss: 0.0191 - val_mae: 0.1463
# Epoch 220/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0079 - mae: 0.1026 - val_loss: 0.0192 - val_mae: 0.1466
# Epoch 221/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0065 - mae: 0.0922 - val_loss: 0.0192 - val_mae: 0.1463
# Epoch 222/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0063 - mae: 0.0895 - val_loss: 0.0189 - val_mae: 0.1453
# Epoch 223/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0092 - mae: 0.1064 - val_loss: 0.0186 - val_mae: 0.1439
# Epoch 224/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0053 - mae: 0.0835 - val_loss: 0.0181 - val_mae: 0.1416
# Epoch 225/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0063 - mae: 0.0849 - val_loss: 0.0177 - val_mae: 0.1400
# Epoch 226/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0070 - mae: 0.0925 - val_loss: 0.0175 - val_mae: 0.1384
# Epoch 227/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0062 - mae: 0.0927 - val_loss: 0.0174 - val_mae: 0.1378
# Epoch 228/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0056 - mae: 0.0814 - val_loss: 0.0173 - val_mae: 0.1373
# Epoch 229/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0057 - mae: 0.0844 - val_loss: 0.0173 - val_mae: 0.1369
# Epoch 230/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0068 - mae: 0.0984 - val_loss: 0.0175 - val_mae: 0.1377
# Epoch 231/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0062 - mae: 0.0895 - val_loss: 0.0177 - val_mae: 0.1386
# Epoch 232/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0080 - mae: 0.1000 - val_loss: 0.0184 - val_mae: 0.1410
# Epoch 233/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0080 - mae: 0.1041 - val_loss: 0.0188 - val_mae: 0.1427
# Epoch 234/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0066 - mae: 0.0948 - val_loss: 0.0194 - val_mae: 0.1444
# Epoch 235/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0081 - mae: 0.0997 - val_loss: 0.0195 - val_mae: 0.1447
# Epoch 236/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0069 - mae: 0.0941 - val_loss: 0.0196 - val_mae: 0.1450
# Epoch 237/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0074 - mae: 0.1001 - val_loss: 0.0195 - val_mae: 0.1445
# Epoch 238/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0057 - mae: 0.0877 - val_loss: 0.0191 - val_mae: 0.1432
# Epoch 239/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0068 - mae: 0.0952 - val_loss: 0.0187 - val_mae: 0.1416
# Epoch 240/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0063 - mae: 0.0897 - val_loss: 0.0185 - val_mae: 0.1412
# Epoch 241/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0076 - mae: 0.0994 - val_loss: 0.0186 - val_mae: 0.1412
# Epoch 242/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0064 - mae: 0.0942 - val_loss: 0.0185 - val_mae: 0.1410
# Epoch 243/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0064 - mae: 0.0895 - val_loss: 0.0184 - val_mae: 0.1405
# Epoch 244/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0064 - mae: 0.0920 - val_loss: 0.0182 - val_mae: 0.1400
# Epoch 245/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0062 - mae: 0.0904 - val_loss: 0.0181 - val_mae: 0.1394
# Epoch 246/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0063 - mae: 0.0871 - val_loss: 0.0182 - val_mae: 0.1397
# Epoch 247/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0073 - mae: 0.0979 - val_loss: 0.0185 - val_mae: 0.1410
# Epoch 248/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0065 - mae: 0.0916 - val_loss: 0.0188 - val_mae: 0.1426
# Epoch 249/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0067 - mae: 0.0929 - val_loss: 0.0190 - val_mae: 0.1433
# Epoch 250/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0075 - mae: 0.0954 - val_loss: 0.0189 - val_mae: 0.1428
# Epoch 251/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0067 - mae: 0.0948 - val_loss: 0.0187 - val_mae: 0.1418
# Epoch 252/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0069 - mae: 0.0899 - val_loss: 0.0182 - val_mae: 0.1396
# Epoch 253/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0060 - mae: 0.0827 - val_loss: 0.0180 - val_mae: 0.1387
# Epoch 254/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0070 - mae: 0.0973 - val_loss: 0.0180 - val_mae: 0.1388
# Epoch 255/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0074 - mae: 0.0961 - val_loss: 0.0181 - val_mae: 0.1393
# Epoch 256/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0073 - mae: 0.0959 - val_loss: 0.0183 - val_mae: 0.1401
# Epoch 257/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0059 - mae: 0.0875 - val_loss: 0.0186 - val_mae: 0.1412
# Epoch 258/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0074 - mae: 0.0960 - val_loss: 0.0190 - val_mae: 0.1430
# Epoch 259/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0063 - mae: 0.0920 - val_loss: 0.0195 - val_mae: 0.1455
# Epoch 260/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0070 - mae: 0.0911 - val_loss: 0.0201 - val_mae: 0.1479
# Epoch 261/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0073 - mae: 0.0995 - val_loss: 0.0205 - val_mae: 0.1499
# Epoch 262/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0073 - mae: 0.0987 - val_loss: 0.0206 - val_mae: 0.1507
# Epoch 263/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0059 - mae: 0.0811 - val_loss: 0.0206 - val_mae: 0.1506
# Epoch 264/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0065 - mae: 0.0926 - val_loss: 0.0203 - val_mae: 0.1491
# Epoch 265/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0063 - mae: 0.0879 - val_loss: 0.0198 - val_mae: 0.1471
# Epoch 266/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0075 - mae: 0.1002 - val_loss: 0.0194 - val_mae: 0.1454
# Epoch 267/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0062 - mae: 0.0866 - val_loss: 0.0191 - val_mae: 0.1441
# Epoch 268/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0061 - mae: 0.0877 - val_loss: 0.0187 - val_mae: 0.1428
# Epoch 269/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - mae: 0.0984 - val_loss: 0.0183 - val_mae: 0.1412
# Epoch 270/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0066 - mae: 0.0961 - val_loss: 0.0181 - val_mae: 0.1405
# Epoch 271/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0065 - mae: 0.0915 - val_loss: 0.0181 - val_mae: 0.1402
# Epoch 272/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0057 - mae: 0.0837 - val_loss: 0.0182 - val_mae: 0.1405
# Epoch 273/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0084 - mae: 0.1017 - val_loss: 0.0185 - val_mae: 0.1417
# Epoch 274/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0064 - mae: 0.0882 - val_loss: 0.0189 - val_mae: 0.1430
# Epoch 275/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0094 - mae: 0.1093 - val_loss: 0.0191 - val_mae: 0.1436
# Epoch 276/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0082 - mae: 0.0990 - val_loss: 0.0192 - val_mae: 0.1437
# Epoch 277/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0064 - mae: 0.0884 - val_loss: 0.0192 - val_mae: 0.1435
# Epoch 278/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0076 - mae: 0.1016 - val_loss: 0.0192 - val_mae: 0.1432
# Epoch 279/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0059 - mae: 0.0841 - val_loss: 0.0193 - val_mae: 0.1432
# Epoch 280/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0075 - mae: 0.0988 - val_loss: 0.0194 - val_mae: 0.1434
# Epoch 281/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0076 - mae: 0.1019 - val_loss: 0.0194 - val_mae: 0.1436
# Epoch 282/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0071 - mae: 0.0925 - val_loss: 0.0193 - val_mae: 0.1436
# Epoch 283/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0067 - mae: 0.0906 - val_loss: 0.0192 - val_mae: 0.1433
# Epoch 284/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0065 - mae: 0.0925 - val_loss: 0.0191 - val_mae: 0.1428
# Epoch 285/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0069 - mae: 0.0936 - val_loss: 0.0193 - val_mae: 0.1437
# Epoch 286/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0061 - mae: 0.0885 - val_loss: 0.0194 - val_mae: 0.1446
# Epoch 287/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0057 - mae: 0.0859 - val_loss: 0.0196 - val_mae: 0.1452
# Epoch 288/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0062 - mae: 0.0902 - val_loss: 0.0196 - val_mae: 0.1452
# Epoch 289/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0053 - mae: 0.0840 - val_loss: 0.0197 - val_mae: 0.1456
# Epoch 290/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0074 - mae: 0.0942 - val_loss: 0.0197 - val_mae: 0.1458
# Epoch 291/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0072 - mae: 0.0952 - val_loss: 0.0196 - val_mae: 0.1454
# Epoch 292/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0059 - mae: 0.0834 - val_loss: 0.0195 - val_mae: 0.1449
# Epoch 293/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0067 - mae: 0.0911 - val_loss: 0.0193 - val_mae: 0.1441
# Epoch 294/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0053 - mae: 0.0835 - val_loss: 0.0191 - val_mae: 0.1426
# Epoch 295/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0047 - mae: 0.0794 - val_loss: 0.0188 - val_mae: 0.1407
# Epoch 296/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0066 - mae: 0.0921 - val_loss: 0.0185 - val_mae: 0.1390
# Epoch 297/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0051 - mae: 0.0835 - val_loss: 0.0185 - val_mae: 0.1386
# Epoch 298/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 0.0069 - mae: 0.0972 - val_loss: 0.0187 - val_mae: 0.1393
# Epoch 299/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0065 - mae: 0.0946 - val_loss: 0.0189 - val_mae: 0.1402
# Epoch 300/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - loss: 0.0050 - mae: 0.0837 - val_loss: 0.0192 - val_mae: 0.1418

# %%
import matplotlib.pyplot as plt
import numpy as np


# Make predictions
y_pred = model.predict(x_test).flatten()
y_true = np.array(y_test).flatten()

# Sort by actual values (optional, just for easier visualization)
sorted_idx = np.argsort(y_true)
y_true_sorted = y_true[sorted_idx]
y_pred_sorted = y_pred[sorted_idx]

# Plot actual vs predicted
plt.figure(figsize=(10, 6))
plt.plot(y_true_sorted, label="Actual", linewidth=2)
plt.plot(y_pred_sorted, label="Predicted", linewidth=2)
plt.title("Actual vs Predicted Values")
plt.xlabel("Sample Index (sorted by actual)")
plt.ylabel("Target Value")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
model.summary()
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_41 (Dense)                │ (None, 64)             │           960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,221 (36.02 KB)
#  Trainable params: 3,073 (12.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6,148 (24.02 KB)

# %%
import joblib
joblib.dump(model, 'hurricane_model.joblib')
# Out:
# ['hurricane_model.joblib']
